# %%
print ("學習Python")
print ("This is No.1")
print ("TRY TRY TRY")
# Out:
# 學習Python
# This is No.1
# TRY TRY TRY

# %% [markdown]
# # head1
# ## head2
# ### head3
# #### head4
# ##### head5
# ###### head6
